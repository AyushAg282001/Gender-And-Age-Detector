# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from PIL import Image, ImageOps
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
from keras import optimizers
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

import warnings
warnings.filterwarnings('ignore')

# %%
images = []
ages = []
genders = []

for i in os.listdir('utkface_aligned_cropped/crop_part1/')[0:8000]:
    split = i.split('_')
    ages.append(int(split[0]))
    genders.append(int(split[1]))
    images.append(Image.open('utkface_aligned_cropped/crop_part1/' + i))

# %%
images = pd.Series(list(images), name = 'Images')
ages = pd.Series(list(ages), name = 'Ages')
genders = pd.Series(list(genders), name = 'Genders')

df = pd.concat([images, ages, genders], axis=1)
df
# Out:
#                                                  Images  Ages  Genders
# 0     <PIL.JpegImagePlugin.JpegImageFile image mode=...   100        1
# 1     <PIL.JpegImagePlugin.JpegImageFile image mode=...   100        1
# 2     <PIL.JpegImagePlugin.JpegImageFile image mode=...   101        1
# 3     <PIL.JpegImagePlugin.JpegImageFile image mode=...    10        0
# 4     <PIL.JpegImagePlugin.JpegImageFile image mode=...    10        0
# ...                                                 ...   ...      ...
# 7995  <PIL.JpegImagePlugin.JpegImageFile image mode=...    63        1
# 7996  <PIL.JpegImagePlugin.JpegImageFile image mode=...    63        1
# 7997  <PIL.JpegImagePlugin.JpegImageFile image mode=...    63        1
# 7998  <PIL.JpegImagePlugin.JpegImageFile image mode=...    63        1
# 7999  <PIL.JpegImagePlugin.JpegImageFile image mode=...    63        1
#
# [8000 rows x 3 columns]

# %%
display(df['Images'][100])
print(df['Ages'][100], df['Genders'][100])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200>
# 10 1

# %%
sns.set_theme()
sns.distplot(df['Ages'],kde=True, bins=30)
# Out:
# C:\Users\ayuag\AppData\Local\Temp\ipykernel_37904\409036286.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Ages'],kde=True, bins=30)
# <AxesSubplot:xlabel='Ages', ylabel='Density'>

# %%
sns.set_theme()
sns.countplot(x=df['Genders'])
# Out:
# <AxesSubplot:xlabel='Genders', ylabel='count'>

# %%
x = []
y = []

for i in range(len(df)):
    df['Images'].iloc[i] = df['Images'].iloc[i].resize((200,200), Image.ANTIALIAS)
    ar = np.asarray(df['Images'].iloc[i])
    x.append(ar)
    agegen = [int(df['Ages'].iloc[i]), int(df['Genders'].iloc[i])]
    y.append(agegen)
x = np.array(x)

# %%
y_age = df[['Ages']]
y_gender = df[['Genders']]

x_train_age, x_test_age, y_train_age, y_test_age = train_test_split(x, y_age, test_size=0.2)
x_train_gender, x_test_gender, y_train_gender, y_test_gender = train_test_split(x, y_gender, test_size=0.2)

# %%
agemodel = Sequential()
agemodel.add(Conv2D(32, (3,3), activation='relu', input_shape=(200, 200, 3)))
agemodel.add(MaxPooling2D((2,2)))
agemodel.add(Conv2D(64, (3,3), activation='relu'))
agemodel.add(MaxPooling2D((2,2)))
agemodel.add(Conv2D(128, (3,3), activation='relu'))
agemodel.add(MaxPooling2D((2,2)))
agemodel.add(Flatten())
agemodel.add(Dense(64, activation='relu'))
agemodel.add(Dropout(0.5))
agemodel.add(Dense(1, activation='relu'))

agemodel.compile(loss='mean_squared_error',
             optimizer=optimizers.Adam(lr=0.0001))

genmodel = Sequential()
genmodel.add(Conv2D(32, (3,3), activation='relu', input_shape=(200, 200, 3)))
genmodel.add(MaxPooling2D((2,2)))
genmodel.add(Conv2D(64, (3,3), activation='relu'))
genmodel.add(MaxPooling2D((2,2)))
genmodel.add(Conv2D(128, (3,3), activation='relu'))
genmodel.add(MaxPooling2D((2,2)))
genmodel.add(Flatten())
genmodel.add(Dense(64, activation='relu'))
genmodel.add(Dropout(0.5))
genmodel.add(Dense(1, activation='sigmoid'))

genmodel.compile(loss='binary_crossentropy',
             optimizer=optimizers.Adam(lr=0.0001),
             metrics=['accuracy'])

# %%
datagen = ImageDataGenerator(
      rescale=1./255., width_shift_range = 0.1, height_shift_range = 0.1, horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

train1 = datagen.flow(x_train_age, y_train_age, batch_size=32)

test1 = test_datagen.flow(
        x_test_age, y_test_age,
    
        batch_size=32)

history1 = agemodel.fit(train1, epochs=50, shuffle=True, validation_data=test1)
# Out:
# Epoch 1/50
# 200/200 [==============================] - 322s 2s/step - loss: 429.9069 - val_loss: 327.3795
# Epoch 2/50
# 200/200 [==============================] - 311s 2s/step - loss: 307.9816 - val_loss: 225.1311
# Epoch 3/50
# 200/200 [==============================] - 292s 1s/step - loss: 260.4377 - val_loss: 202.0082
# Epoch 4/50
# 200/200 [==============================] - 423s 2s/step - loss: 241.4601 - val_loss: 197.5243
# Epoch 5/50
# 200/200 [==============================] - 320s 2s/step - loss: 235.2535 - val_loss: 201.2564
# Epoch 6/50
# 200/200 [==============================] - 328s 2s/step - loss: 220.6931 - val_loss: 186.9985
# Epoch 7/50
# 200/200 [==============================] - 335s 2s/step - loss: 219.9988 - val_loss: 175.3826
# Epoch 8/50
# 200/200 [==============================] - 460s 2s/step - loss: 211.5760 - val_loss: 175.7818
# Epoch 9/50
# 200/200 [==============================] - 414s 2s/step - loss: 210.4312 - val_loss: 167.2726
# Epoch 10/50
# 200/200 [==============================] - 401s 2s/step - loss: 208.4023 - val_loss: 166.0100
# Epoch 11/50
# 200/200 [==============================] - 314s 2s/step - loss: 203.1685 - val_loss: 160.8629
# Epoch 12/50
# 200/200 [==============================] - 321s 2s/step - loss: 197.2687 - val_loss: 158.7602
# Epoch 13/50
# 200/200 [==============================] - 447s 2s/step - loss: 195.6194 - val_loss: 154.6901
# Epoch 14/50
# 200/200 [==============================] - 418s 2s/step - loss: 183.1991 - val_loss: 170.3573
# Epoch 15/50
# 200/200 [==============================] - 470s 2s/step - loss: 191.4796 - val_loss: 222.9325
# Epoch 16/50
# 200/200 [==============================] - 449s 2s/step - loss: 188.4542 - val_loss: 151.6105
# Epoch 17/50
# 200/200 [==============================] - 497s 2s/step - loss: 179.5275 - val_loss: 152.4205
# Epoch 18/50
# 200/200 [==============================] - 479s 2s/step - loss: 180.7226 - val_loss: 150.9097
# Epoch 19/50
# Epoch 48/50
# 200/200 [==============================] - 399s 2s/step - loss: 135.8550 - val_loss: 113.7429
# Epoch 49/50
# 200/200 [==============================] - 408s 2s/step - loss: 139.4794 - val_loss: 116.0982
# Epoch 50/50
# 200/200 [==============================] - 402s 2s/step - loss: 133.8568 - val_loss: 108.2388

# %%
datagen = ImageDataGenerator(
      rescale=1./255., width_shift_range = 0.1, height_shift_range = 0.1, horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

train2 = datagen.flow(x_train_gender, y_train_gender, batch_size=64)

test2 = test_datagen.flow(
        x_test_gender, y_test_gender,
        batch_size=64)

history2 = genmodel.fit(train2, epochs=50, shuffle=True, validation_data=test2)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 392s 4s/step - loss: 0.6590 - accuracy: 0.5961 - val_loss: 0.6316 - val_accuracy: 0.6712
# Epoch 2/50
# 100/100 [==============================] - 394s 4s/step - loss: 0.6180 - accuracy: 0.6519 - val_loss: 0.5886 - val_accuracy: 0.7081
# Epoch 3/50
# 100/100 [==============================] - 397s 4s/step - loss: 0.5945 - accuracy: 0.6727 - val_loss: 0.5527 - val_accuracy: 0.7294
# Epoch 4/50
# 100/100 [==============================] - 398s 4s/step - loss: 0.5730 - accuracy: 0.6902 - val_loss: 0.5393 - val_accuracy: 0.7350
# Epoch 5/50
# 100/100 [==============================] - 339s 3s/step - loss: 0.5598 - accuracy: 0.7089 - val_loss: 0.5144 - val_accuracy: 0.7456
# Epoch 6/50
# 100/100 [==============================] - 310s 3s/step - loss: 0.5387 - accuracy: 0.7289 - val_loss: 0.4995 - val_accuracy: 0.7619
# Epoch 7/50
# 100/100 [==============================] - 291s 3s/step - loss: 0.5313 - accuracy: 0.7197 - val_loss: 0.4778 - val_accuracy: 0.7706
# Epoch 8/50
# 100/100 [==============================] - 288s 3s/step - loss: 0.5246 - accuracy: 0.7361 - val_loss: 0.4819 - val_accuracy: 0.7738
# Epoch 9/50
# 100/100 [==============================] - 294s 3s/step - loss: 0.5130 - accuracy: 0.7308 - val_loss: 0.4707 - val_accuracy: 0.7788
# Epoch 10/50
# 100/100 [==============================] - 286s 3s/step - loss: 0.5124 - accuracy: 0.7406 - val_loss: 0.4572 - val_accuracy: 0.7806
# Epoch 11/50
# 100/100 [==============================] - 289s 3s/step - loss: 0.5174 - accuracy: 0.7367 - val_loss: 0.4645 - val_accuracy: 0.7906
# Epoch 12/50
# 100/100 [==============================] - 290s 3s/step - loss: 0.5103 - accuracy: 0.7492 - val_loss: 0.4617 - val_accuracy: 0.7881
# Epoch 13/50
# 100/100 [==============================] - 283s 3s/step - loss: 0.5006 - accuracy: 0.7503 - val_loss: 0.4400 - val_accuracy: 0.7887
# Epoch 14/50
# 100/100 [==============================] - 287s 3s/step - loss: 0.4937 - accuracy: 0.7547 - val_loss: 0.4346 - val_accuracy: 0.7956
# Epoch 15/50
# 100/100 [==============================] - 291s 3s/step - loss: 0.4956 - accuracy: 0.7567 - val_loss: 0.4368 - val_accuracy: 0.7850
# Epoch 16/50
# 100/100 [==============================] - 285s 3s/step - loss: 0.4865 - accuracy: 0.7620 - val_loss: 0.4294 - val_accuracy: 0.8006
# Epoch 17/50
# 100/100 [==============================] - 284s 3s/step - loss: 0.4916 - accuracy: 0.7580 - val_loss: 0.4342 - val_accuracy: 0.8050
# Epoch 18/50
# 100/100 [==============================] - 291s 3s/step - loss: 0
50
# 100/100 [==============================] - 290s 3s/step - loss: 0.4478 - accuracy: 0.7909 - val_loss: 0.4084 - val_accuracy: 0.8100
# Epoch 38/50
# 100/100 [==============================] - 293s 3s/step - loss: 0.4522 - accuracy: 0.7900 - val_loss: 0.4056 - val_accuracy: 0.8144
# Epoch 39/50
# 100/100 [==============================] - 292s 3s/step - loss: 0.4502 - accuracy: 0.7823 - val_loss: 0.3972 - val_accuracy: 0.8144
# Epoch 40/50
# 100/100 [==============================] - 293s 3s/step - loss: 0.4433 - accuracy: 0.7956 - val_loss: 0.3861 - val_accuracy: 0.8256
# Epoch 41/50
# 100/100 [==============================] - 285s 3s/step - loss: 0.4370 - accuracy: 0.7975 - val_loss: 0.3853 - val_accuracy: 0.8213
# Epoch 42/50
# 100/100 [==============================] - 284s 3s/step - loss: 0.4470 - accuracy: 0.7934 - val_loss: 0.3927 - val_accuracy: 0.8219
# Epoch 43/50
# 100/100 [==============================] - 290s 3s/step - loss: 0.4340 - accuracy: 0.7945 - val_loss: 0.3807 - val_accuracy: 0.8231
# Epoch 44/50
# 100/100 [==============================] - 289s 3s/step - loss: 0.4346 - accuracy: 0.8034 - val_loss: 0.3821 - val_accuracy: 0.8138
# Epoch 45/50
# 100/100 [==============================] - 287s 3s/step - loss: 0.4326 - accuracy: 0.7939 - val_loss: 0.3816 - val_accuracy: 0.8256
# Epoch 46/50
# 100/100 [==============================] - 283s 3s/step - loss: 0.4346 - accuracy: 0.7962 - val_loss: 0.3785 - val_accuracy: 0.8194
# Epoch 47/50
# 100/100 [==============================] - 292s 3s/step - loss: 0.4330 - accuracy: 0.7983 - val_loss: 0.3778 - val_accuracy: 0.8163
# Epoch 48/50
# 100/100 [==============================] - 283s 3s/step - loss: 0.4297 - accuracy: 0.8009 - val_loss: 0.3805 - val_accuracy: 0.8244
# Epoch 49/50
# 100/100 [==============================] - 283s 3s/step - loss: 0.4315 - accuracy: 0.8037 - val_loss: 0.3824 - val_accuracy: 0.8194
# Epoch 50/50
# 100/100 [==============================] - 291s 3s/step - loss: 0.4327 - accuracy: 0.7975 - val_loss: 0.3995 - val_accuracy: 0.8163

# %%
def process_and_predict(file):
    im = Image.open(file)
    width, height = im.size
    if width == height:
        im = im.resize((200,200), Image.ANTIALIAS)
    else:
        if width > height:
            left = width/2 - height/2
            right = width/2 + height/2
            top = 0
            bottom = height
            im = im.crop((left,top,right,bottom))
            im = im.resize((200,200), Image.ANTIALIAS)
        else:
            left = 0
            right = width
            top = 0
            bottom = width
            im = im.crop((left,top,right,bottom))
            im = im.resize((200,200), Image.ANTIALIAS)
            
    ar = np.asarray(im)
    ar = ar.astype('float32')
    ar /= 255.0
    ar = ar.reshape(-1, 200, 200, 3)
    
    age = agemodel.predict(ar)
    gender = np.round(genmodel.predict(ar))
    if gender == 0:
        gender = 'male'
    elif gender == 1:
        gender = 'female'
        
    print('Age:', int(age), '\n Gender:', gender)
    return im.resize((300,300), Image.ANTIALIAS)

# %%
process_and_predict('img1.jpg')
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 41ms/step
# Age: 37
#  Gender: male
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
process_and_predict('img2.jfif')
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 53ms/step
# Age: 38
#  Gender: female
# <PIL.Image.Image image mode=RGB size=300x300>
